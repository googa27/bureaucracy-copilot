# %% [markdown]
# # Finance Exploration
#
# Notebook for exploring Tenpo/BICE financial event data.
#
# ## Setup
#
# Load financial events and analyze spending patterns by category.

# %%
# TODO: import finance pipeline
# from src.finance import load_events
# events = load_events()

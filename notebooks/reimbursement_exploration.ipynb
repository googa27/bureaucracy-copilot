# %% [markdown]
# # Reimbursement Exploration
#
# Notebook for exploring Esencial/BICE VIDA/Clínica Alemana reimbursement data.
#
# ## Setup
#
# Load medical case objects and analyze reimbursement patterns.

# %%
# TODO: import ingestion pipeline
# from src.ingestion import load_cases
# cases = load_cases()
